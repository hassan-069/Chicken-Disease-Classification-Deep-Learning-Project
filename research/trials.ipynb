# %% [markdown]
# DOWNLOAD DATA FROM GDRIVE

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1RQ9vufgEdo-ru-WH4iinjoEmDxTzR6Qa/view?usp=drive_link"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1RQ9vufgEdo-ru-WH4iinjoEmDxTzR6Qa',
#  'view?usp=drive_link']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1RQ9vufgEdo-ru-WH4iinjoEmDxTzR6Qa'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix + file_id, "chicken-disease-images-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1RQ9vufgEdo-ru-WH4iinjoEmDxTzR6Qa
# From (redirected): https://drive.google.com/uc?export=download&id=1RQ9vufgEdo-ru-WH4iinjoEmDxTzR6Qa&confirm=t&uuid=17cc5414-d7fc-45fd-b5bd-d88647e34d43
# To: e:\Deep Learning Projects\Chicken-Disease-Classification-Deep-Learning-Project\research\chicken-disease-images-data.zip
# 100%|██████████| 126M/126M [00:43<00:00, 2.89MB/s]
# 'chicken-disease-images-data.zip'
